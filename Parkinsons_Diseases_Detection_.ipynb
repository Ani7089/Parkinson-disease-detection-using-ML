# %% [markdown]
# # Importing the required Libraries and packages

# %%
import numpy as np
import cv2
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import pandas as pd
from keras.models import load_model

# %%
# !wget https://cainvas-static.s3.amazonaws.com/media/user_data/cainvas-admin/Parkinson_disease_detection.zip
# !unzip -qo Parkinson_disease_detection.zip
# Out:
# --2023-10-06 13:29:59--  https://cainvas-static.s3.amazonaws.com/media/user_data/cainvas-admin/Parkinson_disease_detection.zip
# Resolving cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)... 52.219.64.112, 52.219.160.119, 52.219.158.115, ...
# Connecting to cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)|52.219.64.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8201907 (7.8M) [application/x-zip-compressed]
# Saving to: ‘Parkinson_disease_detection.zip’
#
# Parkinson_disease_d 100%[===================>]   7.82M  15.5MB/s    in 0.5s
#
# 2023-10-06 13:30:00 (15.5 MB/s) - ‘Parkinson_disease_detection.zip’ saved [8201907/8201907]

# %% [markdown]
# # Loading Dataset

# %%
data_train = np.load('Parkinson_disease_detection/train_set.npz', allow_pickle=True)
x_train = data_train['arr_0']
y_train = data_train['arr_1']

print(x_train.shape)
print(y_train.shape)
# Out:
# (72, 256, 256, 3)
# (72,)

# %%
data_test = np.load('Parkinson_disease_detection/test_set.npz', allow_pickle=True)
x_test = data_test['arr_0']
y_test = data_test['arr_1']

print(x_test.shape)
print(y_test.shape)
# Out:
# (30, 256, 256, 3)
# (30,)

# %% [markdown]
# # Data Distribution

# %%
unique_train, count = np.unique(y_train, return_counts=True)
plt.figure(figsize=(15, 7))
sns.barplot(x=unique_train,y= count).set_title("Number of training images per category:")
plt.show()

# %%
unique_test, count_test = np.unique(y_test, return_counts=True)
plt.figure(figsize=(15, 7))
sns.barplot(x=unique_test,y= count_test).set_title("Number of testing images per category:")
plt.show()

# %% [markdown]
# # Augmenting the Dataset

# %%
train_data_generator = ImageDataGenerator(rotation_range=360,
                                    width_shift_range=0.0,
                                    height_shift_range=0.0,
#                                     brightness_range=[0.5, 1.5],
                                    horizontal_flip=True,
                                    vertical_flip=True)

x = list(x_train)
y = list(y_train)

x_aug_train = []
y_aug_train = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = train_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(70):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_train.append(aug_image)
        y_aug_train.append(v)
print(len(x_aug_train))
print(len(y_aug_train))

x_train = x + x_aug_train
y_train = y + y_aug_train
print(len(x_train))
print(len(y_train))

test_data_generator = ImageDataGenerator(rotation_range=360,
                                    width_shift_range=0.0,
                                    height_shift_range=0.0,
#                                     brightness_range=[0.5, 1.5],
                                    horizontal_flip=True,
                                    vertical_flip=True)

x = list(x_test)
y = list(y_test)

x_aug_test = []
y_aug_test = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = test_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(20):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_test.append(aug_image)
        y_aug_test.append(v)
print(len(x_aug_test))
print(len(y_aug_test))

x_test = x + x_aug_test
y_test = y + y_aug_test
print(len(x_test))
print(len(y_test))
# Out:
# 5040
# 5040
# 5112
# 5112
# 600
# 600
# 630
# 630

# %% [markdown]
# # Visualizing the Images in Train and Test Set

# %% [markdown]
# ## Images in Train Set

# %%
# print(y_test)
figure1 = plt.figure(figsize=(5, 5))
idx_healthy = [i for (i, v) in enumerate(y_train) if v=='healthy']
img_healthy = x_train[idx_healthy[-1]]
plt.imshow(img_healthy)
plt.title('Spiral Drawing by a Healthy Person')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_parkinson = [i for (i, v) in enumerate(y_train) if v=='parkinson']
img_parkinson = x_train[idx_parkinson[-1]]
plt.imshow(img_parkinson)
plt.title("Spiral Drawing by a Person having Parkinson's Disease")
plt.axis('off')
plt.show()

# %%
idx_healthy = [i for i, label in enumerate(y_train) if label == 'healthy']

# Loop through the indices and copy the corresponding image files
for idx in idx_healthy:
    image_filename = f'image_{idx}.jpg'  # Replace with the actual image filename pattern
    source_path = os.path.join(source_directory, image_filename)
    destination_path = os.path.join(destination_directory, image_filename)

    if os.path.exists(source_path):
        shutil.copyfile(source_path, destination_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-1991ef8f44b8> in <cell line: 4>()
#       4 for idx in idx_healthy:
#       5     image_filename = f'image_{idx}.jpg'  # Replace with the actual image filename pattern
# ----> 6     source_path = os.path.join(source_directory, image_filename)
#       7     destination_path = os.path.join(destination_directory, image_filename)
#       8
#
# NameError: name 'os' is not defined

# %%
figure1 = plt.figure(figsize=(5, 5))
idx_healthy = [i for (i, v) in enumerate(y_test) if v=='healthy']
img_healthy = x_test[idx_healthy[-1]]
plt.imshow(img_healthy)
plt.title('Spiral Drawing by a Healthy Person')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_parkinson = [i for (i, v) in enumerate(y_test) if v=='parkinson']
img_parkinson = x_test[idx_parkinson[-1]]
plt.imshow(img_parkinson)
plt.title("Spiral Drawing by a Person having Parkinson's Disease")
plt.axis('off')
plt.show()

# %%
for i in range(len(x_train)):
    img = x_train[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_train[i] = img

for i in range(len(x_test)):
    img = x_test[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_test[i] = img

x_train = np.array(x_train)
x_test = np.array(x_test)

x_train = x_train/255.0
x_test = x_test/255.0

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
print(y_train.shape)

label_encoder = LabelEncoder()
y_test = label_encoder.fit_transform(y_test)
print(y_test.shape)
# Out:
# (5112,)
# (630,)

# %%
x_test[1].shape
# Out:
# (128, 128, 1)

# %%
unique_train, count = np.unique(y_train, return_counts=True)
plt.figure(figsize=(15, 7))
sns.barplot(x=unique_train,y=count).set_title("Number of training images per category after augmentation:")
plt.show()

# %%
unique_test, count_test = np.unique(y_test, return_counts=True)
plt.figure(figsize=(15, 7))
sns.barplot(x=unique_test, y=count_test).set_title("Number of test set images per category after augmentation:")
plt.show()

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (5112, 128, 128, 1)
# (5112, 2)
# (630, 128, 128, 1)
# (630, 2)

# %%
def parkinson_disease_detection_model(input_shape=(128, 128, 1)):
    regularizer = tf.keras.regularizers.l2(0.001)
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(128, (5, 5), padding='same', strides=(1, 1), name='conv1', activation='relu',
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((9, 9), strides=(3, 3)))

    model.add(Conv2D(64, (5, 5), padding='same', strides=(1, 1), name='conv2', activation='relu',
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((7, 7), strides=(3, 3)))

    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu',
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((5, 5), strides=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu',
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((3, 3), strides=(2, 2)))

    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_initializer='glorot_uniform', name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer='glorot_uniform', name='fc3'))

    optimizer = Adam(3.15e-5)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model= parkinson_disease_detection_model(input_shape=(128, 128, 1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 128, 128, 128)     3328
#
#  max_pooling2d (MaxPooling2  (None, 40, 40, 128)       0
#  D)
#
#  conv2 (Conv2D)              (None, 40, 40, 64)        204864
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 64)        0
#  g2D)
#
#  conv3 (Conv2D)              (None, 12, 12, 32)        18464
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 32)          0
#  g2D)
#
#  conv4 (Conv2D)              (None, 4, 4, 32)          9248
#
#  max_pooling2d_3 (MaxPoolin  (None, 1, 1, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dropout (Dropout)           (None, 32)                0
#
#  fc1 (Dense)                 (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  fc3 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 238146 (930.26 KB)
# Trainable params: 238146 (930.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
hist = model.fit(x_train, y_train, batch_size=128, epochs=70, validation_data=(x_test, y_test))
# Out:
# Epoch 1/70
# 40/40 [==============================] - 21s 197ms/step - loss: 0.8531 - accuracy: 0.5039 - val_loss: 0.8485 - val_accuracy: 0.5000
# Epoch 2/70
# 40/40 [==============================] - 5s 114ms/step - loss: 0.8453 - accuracy: 0.5063 - val_loss: 0.8417 - val_accuracy: 0.5000
# Epoch 3/70
# 40/40 [==============================] - 5s 116ms/step - loss: 0.8388 - accuracy: 0.5037 - val_loss: 0.8352 - val_accuracy: 0.5000
# Epoch 4/70
# 40/40 [==============================] - 5s 117ms/step - loss: 0.8322 - accuracy: 0.5070 - val_loss: 0.8294 - val_accuracy: 0.5000
# Epoch 5/70
# 40/40 [==============================] - 5s 117ms/step - loss: 0.8262 - accuracy: 0.5108 - val_loss: 0.8232 - val_accuracy: 0.5000
# Epoch 6/70
# 40/40 [==============================] - 5s 113ms/step - loss: 0.8209 - accuracy: 0.5149 - val_loss: 0.8178 - val_accuracy: 0.5270
# Epoch 7/70
# 40/40 [==============================] - 5s 115ms/step - loss: 0.8155 - accuracy: 0.5123 - val_loss: 0.8126 - val_accuracy: 0.6476
# Epoch 8/70
# 40/40 [==============================] - 5s 117ms/step - loss: 0.8107 - accuracy: 0.5096 - val_loss: 0.8077 - val_accuracy: 0.5317
# Epoch 9/70
# 40/40 [==============================] - 5s 117ms/step - loss: 0.8061 - accuracy: 0.5174 - val_loss: 0.8028 - val_accuracy: 0.7079
# Epoch 10/70
# 40/40 [==============================] - 5s 118ms/step - loss: 0.8018 - accuracy: 0.5151 - val_loss: 0.7988 - val_accuracy: 0.6127
# Epoch 11/70
# 40/40 [==============================] - 5s 119ms/step - loss: 0.7980 - accuracy: 0.5239 - val_loss: 0.7948 - val_accuracy: 0.6968
# Epoch 12/70
# 40/40 [==============================] - 5s 117ms/step - loss: 0.7931 - accuracy: 0.5552 - val_loss: 0.7903 - val_accuracy: 0.7000
# Epoch 13/70
# 40/40 [==============================] - 5s 120ms/step - loss: 0.7901 - accuracy: 0.5305 - val_loss: 0.7859 - val_accuracy: 0.6778
# Epoch 14/70
# 40/40 [==============================] - 5s 120ms/step - loss: 0.7862 - accuracy: 0.5356 - val_loss: 0.7823 - val_accuracy: 0.7095
# Epoch 15/70
# 40/40 [==============================] - 5s 122ms/step - loss: 0.7832 - accuracy: 0.5356 - val_loss: 0.7783 - val_accuracy: 0.7079
# Epoch 16/70
# 40/40 [==============================] - 5s 121ms/step - loss: 0.7787 - accuracy: 0.5589 - val_loss: 0.7745 - val_accuracy: 0.7079
# Epoch 17/70
# 40/40 [==============================] - 5s 117ms/step - loss: 0.7758 - accuracy: 0.5577 - val_loss: 0.7712 - val_accuracy: 0.6032
# Epoch 18/70
# 40/40 [==============================] - 5s 119ms/step - loss: 0.7723 - accuracy: 0.5720 - val_loss: 0.7663 - val_accuracy: 0.6730
# Epoch 19/70
# 40/40 [==============================] - 5s 117ms/step - loss: 0.7670 - accuracy: 0.5859 - val_loss: 0.7619 - val_accuracy: 0.6143
# Epoch 20/70
# 40/40 [==============================] - 5s 120ms/step - loss: 0.7635 - accuracy: 0.5974 - val_loss: 0.7560 - val_accuracy: 0.7587
# Epoch 21/70
# 40/40 [==============================] - 5s 119ms/step - loss: 0.7557 - accuracy: 0.6119 - val_loss: 0.7503 - val_accuracy: 0.7016
# Epoch 22/70
# 40/40 [==============================] - 5s 123ms/step - loss: 0.7520 - accuracy: 0.6101 - val_loss: 0.7443 - val_accuracy: 0.7127
# Epoch 23/70
# 40/40 [==============================] - 5s 124ms/step - loss: 0.7438 - accuracy: 0.6363 - val_loss: 0.7374 - val_accuracy: 0.6333
# Epoch 24/70
# 40/40 [==============================] - 5s 123ms/step - loss: 0.7343 - accuracy: 0.6604 - val_loss: 0.7279 - val_accuracy: 0.6952
# Epoch 25/70
# 40/40 [==============================] - 5s 125ms/step - loss: 0.7266 - accuracy: 0.6641 - val_loss: 0.7128 - val_accuracy: 0.7841
# Epoch 26/70
# 40/40 [==============================] - 5s 125ms/step - loss: 0.7118 - accuracy: 0.6929 - val_loss: 0.6991 - val_accuracy: 0.7365
# Epoch 27/70
# 40/40 [==============================] - 5s 126ms/step - loss: 0.7014 - accuracy: 0.7003 - val_loss: 0.7033 - val_accuracy: 0.6540
# Epoch 28/70
# 40/40 [==============================] - 5s 124ms/step - loss: 0.6895 - accuracy: 0.7034 - val_loss: 0.6761 - val_accuracy: 0.7143
# Epoch 29/70
# 40/40 [==============================] - 5s 127ms/step - loss: 0.6773 - accuracy: 0.7074 - val_loss: 0.6590 - val_accuracy: 0.7429
# Epoch 30/70
# 40/40 [==============================] - 5s 129ms/step - loss: 0.6617 - accuracy: 0.7210 - val_loss: 0.6791 - val_accuracy: 0.6619
# Epoch 31/70
# 40/40 [==============================] - 5s 128ms/step - loss: 0.6440 - accuracy: 0.7443 - val_loss: 0.6452 - val_accuracy: 0.6937
# Epoch 32/70
# 40/40 [==============================] - 5s 129ms/step - loss: 0.6337 - accuracy: 0.7586 - val_loss: 0.6208 - val_accuracy: 0.7937
# Epoch 33/70
# 40/40 [==============================] - 5s 128ms/step - loss: 0.6232 - accuracy: 0.7565 - val_loss: 0.6119 - val_accuracy: 0.7540
# Epoch 34/70
# 40/40 [==============================] - 5s 123ms/step - loss: 0.6136 - accuracy: 0.7568 - val_loss: 0.6211 - val_accuracy: 0.6952
# Epoch 35/70
# 40/40 [==============================] - 5s 124ms/step - loss: 0.5991 - accuracy: 0.7655 - val_loss: 0.5878 - val_accuracy: 0.7667
# Epoch 36/70
# 40/40 [==============================] - 5s 123ms/step - loss: 0.5919 - accuracy: 0.7688 - val_loss: 0.5848 - val_accuracy: 0.7413
# Epoch 37/70
# 40/40 [==============================] - 5s 122ms/step - loss: 0.5814 - accuracy: 0.7741 - val_loss: 0.5724 - val_accuracy: 0.7571
# Epoch 38/70
# 40/40 [==============================] - 5s 123ms/step - loss: 0.5665 - accuracy: 0.7823 - val_loss: 0.5630 - val_accuracy: 0.8000
# Epoch 39/70
# 40/40 [==============================] - 5s 126ms/step - loss: 0.5676 - accuracy: 0.7815 - val_loss: 0.5602 - val_accuracy: 0.7540
# Epoch 40/70
# 40/40 [==============================] - 5s 127ms/step - loss: 0.5657 - accuracy: 0.7829 - val_loss: 0.5465 - val_accuracy: 0.7810
# Epoch 41/70
# 40/40 [==============================] - 5s 122ms/step - loss: 0.5480 - accuracy: 0.7952 - val_loss: 0.5453 - val_accuracy: 0.7651
# Epoch 42/70
# 40/40 [==============================] - 5s 127ms/step - loss: 0.5489 - accuracy: 0.7930 - val_loss: 0.5355 - val_accuracy: 0.7873
# Epoch 43/70
# 40/40 [==============================] - 5s 123ms/step - loss: 0.5490 - accuracy: 0.7975 - val_loss: 0.5348 - val_accuracy: 0.8048
# Epoch 44/70
# 40/40 [==============================] - 5s 126ms/step - loss: 0.5303 - accuracy: 0.8044 - val_loss: 0.5434 - val_accuracy: 0.7556
# Epoch 45/70
# 40/40 [==============================] - 5s 128ms/step - loss: 0.5265 - accuracy: 0.8034 - val_loss: 0.5248 - val_accuracy: 0.7841
# Epoch 46/70
# 40/40 [==============================] - 5s 127ms/step - loss: 0.5121 - accuracy: 0.8179 - val_loss: 0.5195 - val_accuracy: 0.7984
# Epoch 47/70
# 40/40 [==============================] - 5s 128ms/step - loss: 0.5036 - accuracy: 0.8177 - val_loss: 0.5152 - val_accuracy: 0.7841
# Epoch 48/70
# 40/40 [==============================] - 5s 124ms/step - loss: 0.4975 - accuracy: 0.8196 - val_loss: 0.5113 - val_accuracy: 0.7825
# Epoch 49/70
# 40/40 [==============================] - 5s 127ms/step - loss: 0.4893 - accuracy: 0.8273 - val_loss: 0.5112 - val_accuracy: 0.7714
# Epoch 50/70
# 40/40 [==============================] - 5s 124ms/step - loss: 0.4926 - accuracy: 0.8259 - val_loss: 0.5235 - val_accuracy: 0.7762
# Epoch 51/70
# 40/40 [==============================] - 5s 123ms/step - loss: 0.4866 - accuracy: 0.8298 - val_loss: 0.5108 - val_accuracy: 0.8079
# Epoch 52/70
# 40/40 [==============================] - 5s 128ms/step - loss: 0.4766 - accuracy: 0.8320 - val_loss: 0.5248 - val_accuracy: 0.8063
# Epoch 53/70
# 40/40 [==============================] - 5s 124ms/step - loss: 0.4666 - accuracy: 0.8386 - val_loss: 0.5061 - val_accuracy: 0.8048
# Epoch 54/70
# 40/40 [==============================] - 5s 123ms/step - loss: 0.4659 - accuracy: 0.8419 - val_loss: 0.5010 - val_accuracy: 0.7952
# Epoch 55/70
# 40/40 [==============================] - 5s 125ms/step - loss: 0.4512 - accuracy: 0.8449 - val_loss: 0.4996 - val_accuracy: 0.7921
# Epoch 56/70
# 40/40 [==============================] - 5s 123ms/step - loss: 0.4455 - accuracy: 0.8462 - val_loss: 0.5084 - val_accuracy: 0.7921
# Epoch 57/70
# 40/40 [==============================] - 5s 128ms/step - loss: 0.4370 - accuracy: 0.8535 - val_loss: 0.5003 - val_accuracy: 0.7857
# Epoch 58/70
# 40/40 [==============================] - 5s 123ms/step - loss: 0.4396 - accuracy: 0.8529 - val_loss: 0.5196 - val_accuracy: 0.7889
# Epoch 59/70
# 40/40 [==============================] - 5s 123ms/step - loss: 0.4286 - accuracy: 0.8582 - val_loss: 0.5177 - val_accuracy: 0.7794
# Epoch 60/70
# 40/40 [==============================] - 5s 124ms/step - loss: 0.4382 - accuracy: 0.8492 - val_loss: 0.5448 - val_accuracy: 0.7968
# Epoch 61/70
# 40/40 [==============================] - 5s 123ms/step - loss: 0.4398 - accuracy: 0.8515 - val_loss: 0.5106 - val_accuracy: 0.7714
# Epoch 62/70
# 40/40 [==============================] - 5s 128ms/step - loss: 0.4229 - accuracy: 0.8631 - val_loss: 0.5100 - val_accuracy: 0.7889
# Epoch 63/70
# 40/40 [==============================] - 5s 126ms/step - loss: 0.4197 - accuracy: 0.8621 - val_loss: 0.5143 - val_accuracy: 0.7762
# Epoch 64/70
# 40/40 [==============================] - 5s 127ms/step - loss: 0.4080 - accuracy: 0.8728 - val_loss: 0.5602 - val_accuracy: 0.7952
# Epoch 65/70
# 40/40 [==============================] - 5s 125ms/step - loss: 0.4230 - accuracy: 0.8625 - val_loss: 0.5272 - val_accuracy: 0.7952
# Epoch 66/70
# 40/40 [==============================] - 5s 127ms/step - loss: 0.4018 - accuracy: 0.8748 - val_loss: 0.5145 - val_accuracy: 0.7825
# Epoch 67/70
# 40/40 [==============================] - 5s 124ms/step - loss: 0.3911 - accuracy: 0.8809 - val_loss: 0.5430 - val_accuracy: 0.7794
# Epoch 68/70
# 40/40 [==============================] - 5s 124ms/step - loss: 0.3920 - accuracy: 0.8768 - val_loss: 0.5288 - val_accuracy: 0.7857
# Epoch 69/70
# 40/40 [==============================] - 5s 123ms/step - loss: 0.3834 - accuracy: 0.8852 - val_loss: 0.5162 - val_accuracy: 0.7810
# Epoch 70/70
# 40/40 [==============================] - 5s 125ms/step - loss: 0.3820 - accuracy: 0.8856 - val_loss: 0.5442 - val_accuracy: 0.7746

# %%
figure = plt.figure(figsize=(3, 3))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(3, 3))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
ypred = model.predict(x_test)
ypred = np.argmax(ypred, axis=1)
y_test_pred = np.argmax(y_test, axis=1)
print(classification_report(y_test_pred, ypred))
# Out:
# 20/20 [==============================] - 1s 21ms/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.72      0.76       315
#            1       0.75      0.83      0.79       315
#
#     accuracy                           0.77       630
#    macro avg       0.78      0.77      0.77       630
# weighted avg       0.78      0.77      0.77       630

# %%
matrix = confusion_matrix(y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=[0, 1], columns=[0, 1])
figure = plt.figure(figsize=(8, 8))
sns.heatmap(df_cm, annot=True, fmt='d')
# Out:
# <Axes: >

# %%
model.save('parkinson_disease_detection.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pickle
filename = 'linear_model.sav'
# pickle.dump(model, open(filename, 'wb'))

# load the model
#model = pickle.load(open("/content/drive/MyDrive/linear_model.sav", 'rb'))
model = load_model('/content/parkinson_disease_detection.h5')

# %%
labels = ['Healthy', 'Parkinson']
image_healthy = cv2.imread('Parkinson_disease_detection/test_image_healthy.png')
image_parkinson = cv2.imread('Parkinson_disease_detection/test_image_parkinson.png')

image_healthy = cv2.resize(image_healthy, (128, 128))
image_healthy = cv2.cvtColor(image_healthy, cv2.COLOR_BGR2GRAY)
image_healthy = np.array(image_healthy)
image_healthy = np.expand_dims(image_healthy, axis=0)
image_healthy = np.expand_dims(image_healthy, axis=-1)

image_parkinson = cv2.resize(image_parkinson, (128, 128))
image_parkinson = cv2.cvtColor(image_parkinson, cv2.COLOR_BGR2GRAY)
image_parkinson = np.array(image_parkinson)
image_parkinson = np.expand_dims(image_parkinson, axis=0)
image_parkinson = np.expand_dims(image_parkinson, axis=-1)

# %%
ypred_healthy = model.predict(image_healthy)
ypred_parkinson = model.predict(image_parkinson)
# Out:
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 38ms/step

# %%
figure = plt.figure(figsize=(2, 2))
img_healthy = np.squeeze(image_healthy, axis=0)  #img_healthy = img_healthy.squeeze(axis=-1)
plt.imshow(img_healthy)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_healthy[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
image_parkinson = np.squeeze(image_parkinson, axis=0)
plt.imshow(image_parkinson)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_parkinson[0], axis=0)]}')
plt.show()
